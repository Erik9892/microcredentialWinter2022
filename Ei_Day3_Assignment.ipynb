# %% [markdown]
# # Lopping

# %% [markdown]
# ### 1. Create a list that holds 5 data variables.

# %%
TV_Shows = ['game of thrones', 'star trek', 'stranger things','mtrix']

# %% [markdown]
# ### 2. Print out those variables by using a for loop.

# %%
for show in TV_Shows:
  print(show)
# Out:
# game of thrones
# star trek
# stranger things
# mtrix

# %% [markdown]
# ### 3. Modify your for loop to add a message to your for loop.

# %%
for show in TV_Shows:
  print(show.upper() + ' is one of my fav TV shows')
# Out:
# GAME OF THRONES is one of my fav TV shows
# STAR TREK is one of my fav TV shows
# STRANGER THINGS is one of my fav TV shows
# MTRIX is one of my fav TV shows

# %% [markdown]
# ### 4. Use a for loop to print even numbers from 1-20.

# %%
for num in range(1,20):
  if num % 2 == 0:
    print(num)
# Out:
# 2
# 4
# 6
# 8
# 10
# 12
# 14
# 16
# 18

# %% [markdown]
# ### 5. Sort your list in alphabetic order.

# %%
TV_Shows = ['game of thrones', 'star trek', 'stranger things','mtrix']
TV_Shows.sort()
print(TV_Shows)
# Out:
# ['game of thrones', 'mtrix', 'star trek', 'stranger things']

# %% [markdown]
# ###  6. Print out the first three elements of your list.

# %%
TV_Shows = ['game of thrones', 'star trek', 'stranger things','mtrix']
print(TV_Shows[0])
print(TV_Shows[1])
print(TV_Shows[3])
# Out:
# game of thrones
# star trek
# mtrix

# %% [markdown]
# ### 7. Create a loop to print the last 2 elements of your list.

# %%
TV_Shows = ['game of thrones', 'star trek', 'stranger things','mtrix']
print(TV_Shows[-2:])
# Out:
# ['stranger things', 'mtrix']

# %% [markdown]
# # Python Dictionaries

# %% [markdown]
# ###  1. Create a simple dictionary that stores 2 variables, for example: first and last name.

# %%
patient_1 = {'first_name': 'John', 'last_name': 'Kimble' }

# %% [markdown]
# ###  2. Print out those variables stored in your previous dictionary.

# %%
patient_1 = {'first_name': 'John', 'last_name': 'Kimble' }
print(patient_1['first_name'])
print(patient_1['last_name'])
# Out:
# John
# Kimble

# %% [markdown]
# 3.Add a message to those variables on printing: for example: “Hello, firstname lastname!”

# %%
patient_1 = {'first_name': 'John', 'last_name': 'Kimble'}
first_name = patient_1['first_name']
last_name = patient_1['last_name']
print('Hello There,' + ' '  + first_name +',' + ' ' + last_name + '!')
# Out:
# Hello There, John, Kimble!

# %% [markdown]
# ### 4. Create a dictionary that holds 2 key: value pairs:
# a. Look through your dictionary and print each pair,

# %%
Adult_1= {'sex': 'M', 'age': '20'}
for keys, value in Adult_1.items():
    print( keys + value)
# Out:
# sexM
# age20

# %% [markdown]
# ### 5. Create a nested dictionary containing three dictionaries – these dictionaries could be
# anything (favorite pets, travel locations, etc.)
# a. Loop through the dictionaries and print a message for each.

# %% [markdown]
# <a href="https://colab.research.google.com/github/niteen11/lagcc_data_analytics_micro_credential/blob/master/Unit%203%20-%20Python%20Advanced/Mini%20Project/COVID19_DATA_ANALYSIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # COVID 19 Data Analysis

# %% [markdown]
# **Description:** This script will read the latest data from the New York Times' county-level COVID-19 database at https://github.com/nytimes/covid-19-data/blob/master/us-counties.csv, filter the data for a chosen county in a chosen state, calculate the daily count of new cases and new deaths, print the most recent 28 days' worth of data for the selected county, and save the county's data for all dates to a comma-separated value (.csv) file on your computer. The printed data can be copied and pasted directly into a spreadsheet for further analysis and visualization.
#
# **Note:** For information about the data, see https://github.com/nytimes/covid-19-data.
#
# **Note:** After you have run the script one time in a given Anaconda environment, you may reduce the script's execution time by adding a `#` in front of `pip install pandas`. For example, `#pip install pandas` instead of `pip install pandas`. The `#` will tell Python to skip the code without running it.

# %% [markdown]
# # Task 1 : Environment Set up

# %% [markdown]
# Import all required libraries that are needed for data analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

# %% [markdown]
# # Task 2 :  Data Collection

# %% [markdown]
# Use nytimes github repository as a data source to collect the covid 19 data in real time and ingest it into colab notebook for data anlysis purpose

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-states.csv')

# %%
df.head()
# Out:
#          date       state  fips  cases  deaths
# 0  2020-01-21  Washington    53      1       0
# 1  2020-01-22  Washington    53      1       0
# 2  2020-01-23  Washington    53      1       0
# 3  2020-01-24    Illinois    17      1       0
# 4  2020-01-24  Washington    53      1       0

# %%
df.shape
# Out:
# (37638, 5)

# %%
df.columns
# Out:
# Index(['date', 'state', 'fips', 'cases', 'deaths'], dtype='object')

# %%
# Droping colum 
df = df.drop(['fips'], axis= 1)

# %%
df
# Out:
#              date          state    cases  deaths
# 0      2020-01-21     Washington        1       0
# 1      2020-01-22     Washington        1       0
# 2      2020-01-23     Washington        1       0
# 3      2020-01-24       Illinois        1       0
# 4      2020-01-24     Washington        1       0
# ...           ...            ...      ...     ...
# 37633  2022-01-13       Virginia  1334198   15785
# 37634  2022-01-13     Washington  1030529   10226
# 37635  2022-01-13  West Virginia   372674    5503
# 37636  2022-01-13      Wisconsin  1270126   11593
# 37637  2022-01-13        Wyoming   124986    1588
#
# [37638 rows x 4 columns]

# %% [markdown]
# # Task 3 : Data Wrangling and EDA (Exploratory Data Analysis)

# %% [markdown]
# Analyz state data for Covid 19

# %%
latest_df
# Out:
#              date                     state    cases  deaths
# 37582  2022-01-13                   Alabama  1004622   16641
# 37583  2022-01-13                    Alaska   172018     961
# 37584  2022-01-13            American Samoa        1       0
# 37585  2022-01-13                   Arizona  1542936   25002
# 37586  2022-01-13                  Arkansas   653789    9390
# 37587  2022-01-13                California  6716565   77839
# 37588  2022-01-13                  Colorado  1090405   10780
# 37589  2022-01-13               Connecticut   628789    9442
# 37590  2022-01-13                  Delaware   218486    2380
# 37591  2022-01-13      District of Columbia   120327    1245
# 37592  2022-01-13                   Florida  4933518   63081
# 37593  2022-01-13                   Georgia  2040258   30673
# 37594  2022-01-13                      Guam    23448     275
# 37595  2022-01-13                    Hawaii   152811    1111
# ...

# %% [markdown]
# Analyzing New York state data for Covid 19

# %%
ny_df = df[df['state']=='New York']

# %%
ny_df.head()
# Out:
#            date     state  cases  deaths
# 246  2020-03-01  New York      1       0
# 261  2020-03-02  New York      1       0
# 276  2020-03-03  New York      2       0
# 293  2020-03-04  New York     11       0
# 313  2020-03-05  New York     22       0

# %%
# the shape of NY
ny_df.shape
# Out:
# (684, 4)

# %%
ny_df.tail()
# Out:
#              date     state    cases  deaths
# 37392  2022-01-09  New York  4136861   60083
# 37448  2022-01-10  New York  4194745   60162
# 37504  2022-01-11  New York  4244155   60428
# 37560  2022-01-12  New York  4299066   60638
# 37616  2022-01-13  New York  4361115   60876

# %%
latest_df = df.tail(56)

# %%
#The first death in New York
first_ny_death = ny_df[ny_df['deaths']!=0]
first_ny_death.head()
# Out:
#            date     state  cases  deaths
# 669  2020-03-14  New York    610       2
# 722  2020-03-15  New York    732       6
# 775  2020-03-16  New York    950      10
# 828  2020-03-17  New York   1375      18
# 882  2020-03-18  New York   2387      32

# %%
#number of cases in total
ny_df['cases'].max()
# Out:
# 4361115

# %%
# Because the data is cumulative, this method of determining total count is incorrect.
ny_df['cases'].sum()
# Out:
# 953601238

# %% [markdown]
# Finding new covid 19 cases on daily basis (new cases added everyday)

# %%
#new cases for NY
# type(ny_df['cases'])

newcase = []
previuos_case = 0
for index, row in ny_df.iterrows():
  current_case = row['cases']
  newcase_count = current_case - previuos_case
  previuos_case = current_case
  newcase.append(newcase_count)
  # print(newcase_count)

# %%
ny_df['new_cases'] = newcase
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ny_df.head(10)
# Out:
#            date     state  cases  deaths  new_cases
# 246  2020-03-01  New York      1       0          1
# 261  2020-03-02  New York      1       0          0
# 276  2020-03-03  New York      2       0          1
# 293  2020-03-04  New York     11       0          9
# 313  2020-03-05  New York     22       0         11
# 338  2020-03-06  New York     44       0         22
# 369  2020-03-07  New York     89       0         45
# 404  2020-03-08  New York    106       0         17
# 440  2020-03-09  New York    142       0         36
# 478  2020-03-10  New York    173       0         31

# %%
ny_df['new_cases'].sum()
# Out:
# 4361115

# %%
ny_cases = ny_df['cases']
ny_deaths = ny_df['deaths']
ny_dates = ny_df['date']
ny_new_cases = ny_df['new_cases']

# %%
ny_dates
# Out:
# 246      2020-03-01
# 261      2020-03-02
# 276      2020-03-03
# 293      2020-03-04
# 313      2020-03-05
#             ...
# 37392    2022-01-09
# 37448    2022-01-10
# 37504    2022-01-11
# 37560    2022-01-12
# 37616    2022-01-13
# Name: date, Length: 684, dtype: object

# %%
type(ny_new_cases)
# Out:
# pandas.core.series.Series

# %%
ny_df.plot(kind='bar')

# %%
plt.figure(figsize=(15,7))
plt.bar(x=ny_dates, height=ny_new_cases, color='red')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Task4: Understand NY covid 19 data in last 30 days

# %%
ny_cases_30 = ny_df['cases'][-31:-1]
ny_deaths_30 = ny_df['deaths'] [-31:-1]
ny_dates_30 = ny_df['date'][-31:-1]
ny_new_cases_30 = ny_df['new_cases'][-31:-1]

# %%
# ny_dates_30

# %%
plt.figure(figsize=(15,7))
plt.bar(x=ny_dates_30, height=ny_new_cases_30, color='red')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.bar(x=ny_dates_30, height=ny_deaths_30, color='blue')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Comparing Covid 19 data with different states

# %% [markdown]
# Let's compare the Covid 19 cases after July for states: New York, California, Florida, Texas, Arizona

# %%
states = ['California', 'Texas', 'Florida', 'New York', 'Pennsylvania']

# %%
plt.figure(figsize=(15,10))
for state in states:
  df_st = df[(df['state']==state) & (df['date']>='2020-11-01')]
  plt.plot(df_st['date'],
           df_st['cases'],
           linewidth=2
           )
  plt.xticks(rotation=90)
plt.xlabel('Dates')
plt.ylabel('Overall Number of Cases (in millions)')
plt.legend(states)
plt.show()

# %%
ca_df = df[df['state']=='California']
ca_cases = ca_df['cases']
ca_deaths = ca_df['deaths']

tx_df = df[df['state']=='Texas']
tx_cases = tx_df['cases']
tx_deaths = tx_df['deaths']

fl_df = df[df['state']=='Florida']
fl_cases = fl_df['cases']
fl_deaths = fl_df['deaths']

pa_df = df[df['state']=='Pennsylvania']
pa_cases = pa_df['cases']
pa_deaths = pa_df['deaths']

# %%
# !pip install jupyter_dash
from plotly import __version__
import cufflinks as cf 
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode()
import plotly.express as px

import plotly.graph_objects as go
from jupyter_dash import JupyterDash
from dash import dcc
from dash import html
from dash.dependencies import Input, Output
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
fig4 = px.bar(df, x=['cases','deaths'], y='state',            
             labels={'value':'Population', 'variable':'Key'}, height=1000,
             barmode='overlay')

# %%
app = JupyterDash(__name__)
app.layout = html.Div([dcc.Graph(figure=fig4)])
app.run_server(mode='inline')

# %% [markdown]
# # Conclusion

# %% [markdown]
# Below are the conclusions:
#
#
#
# 1.   Conclusion 1
#      --Your text here
# 2.   Conclusion 2
#      --Your text here>

# %% [markdown]
# # Conclusion 1 - While the number of new cases per day in New York has increased over the previous 30 days, the number of deaths per day has remained relatively low. This means that when omicron first arrived in New York, the mortality rate remained low, even while the infection rate increased overall.

# %% [markdown]
# # Conclusion 2 - the number of new cases per day in the US has grown in the last 30 days, the number of deaths per day has remained relatively low. This suggests that when omicron initially came in the United States, the fatality rate was modest, even if the infection rate grew and was less lethal than the original covid-19.

# %% [markdown]
# # Hello Python

# %%
#Variables
#Every variable holds a value- which is the information associated with the variable aka "message"
#in this case the value is "hello world" or 'General Kenobi'
print ('Hello World') 
print('General Kenobi')
# Out:
# Hello World
# General Kenobi

# %%
#There are a few rules and guidelines when creating variables.
#Variable names can only contain letters, numbers,and underscores.
#They can start with a letter or underscore, but not with a number.
#Spaces are not allowed in variable names, but underscore.

print ('Is 1_message a good variable name? How about greeting_message, or message_1 New?')
# Out:
# Is 1_message a good variable name? How about greeting_message, or message_1 New?

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# # Strings

# %%
#A string is a series of characters.
#Anything is quotes is considered a string in Python.
'This is a string.'
"Hello there friends!"
#You can use single or double quotes around your strings – this allows for:
print('I told my friend, “I love Python!')
"The author said ‘Python is the best’"
# Out:
# I told my friend, “I love Python!
# 'The author said ‘Python is the best’'

# %%
'Hi there'
# Out:
# 'Hi there'

# %%
"General Kenobi"
# Out:
# 'General Kenobi'

# %%
"I'm nice"
# Out:
# "I'm nice"

# %%
'I\'m nice'
# Out:
# "I'm nice"

# %% [markdown]
# ## String Basic

# %%
# number of the number of items in a list,in other words the number of characters in the string
len('Hello there')
# Out:
# 11

# %%
#The s signifies that you want to add a string value(variable) into a string.
# Assign s as a string
s = 'General Kenobi'

# %%
#Check
s
# Out:
# 'General Kenobi'

# %%
# Printing the object
print(s)
# Out:
# General Kenobi

# %%
len(s)
# Out:
# 14

# %%
len('General Kenobi')
# Out:
# 14

# %% [markdown]
# ##String Indexing

# %%
#We know strings are a sequence, which means Python can use indexes to call parts of the sequence. Let's learn how this works.
#In Python, we use brackets [] after an object to call its index. We should also note that indexing starts at 0 for Python. 
# in other words it will tell you the positon of the characters ,let's create a new object called s and the walk through a few examples of indexing.

# Show first element (in this case a letter)
s[0]
# Out:
# 'G'

# %%
# Show second element (in this case a letter)
s[1]
# Out:
# 'e'

# %%
# Show Third element (in this case a letter)
s[2]
# Out:
# 'n'

# %%
# Show Fourth element (in this case a letter)
s[3]
# Out:
# 'e'

# %%
# Show fifth element (in this case a letter)
s[4]
# Out:
# 'r'

# %%
# Show sixth element (in this case a letter)
s[5]
# Out:
# 'a'

# %%
# Show seventh element (in this case a letter)
s[6]
# Out:
# 'l'

# %%
# Show eighth element (in this case a letter)
s[7]
# Out:
# ' '

# %%
# Show ninth element (in this case a letter)
s[8]
# Out:
# 'K'
